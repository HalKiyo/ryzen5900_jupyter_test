# %%
import numpy as np

def load(inkey, outkey):
    infile = f"/docker/mnt/d/research/D2/cnn3/predictors/{inkey}.npy"
    outfile = f"/docker/mnt/d/research/D2/cnn3/predictant/continuous/{outkey}.npy"
    predictors = np.load(infile)
    predictant = np.load(outfile)
    return predictors, predictant

# %%
import numpy.ma as ma

def fill(x):
    f = ma.filled(x, fill_value=99999)
    return f

def mask(x):
    m = ma.masked_where(x>9999, x)
    return m

def conc(x):
    c = x.copy()
    c = fill(c)
    x1, x2 = c[:, :, :, -36:], c[:, :, :,:36]
    c = np.concatenate([x1, x2], 3)
    return c

# %% [markdown]
# # 5x5 land

# %%
tors = 'predictors_coarse_std_Apr_msot'
tand = 'pr_1x1_std_MJJASO_thailand'
predictors, predictand = load(tors, tand)
print(predictors.shape, predictand.shape)
# Out:
# (4, 42, 165, 24, 72) (42, 165, 20, 20)

# %%
import matplotlib.pyplot as plt

# 0: moisture, 1: snow, 2: sst, 3: land-tmp
plt.imshow(predictors[2, 0, 0, :, :])

# %%
# 領域を分解する

ocean = predictors[2,0,0,6:18,9:57]
print(ocean.shape)
plt.imshow(ocean)
# Out:
# (12, 48)

# %%
recentered = conc(predictors[0,:,:,:,:])
print(recentered.shape)
plt.imshow(recentered[1, 3])
# Out:
# (42, 165, 24, 72)

# %%
land = recentered[:, :, :12, 12:-12]
print(land.shape)
plt.imshow(mask(land[0,0]))
# Out:
# (42, 165, 12, 48)

# %% [markdown]
# # 1x1 land

# %%
tors = 'predictors_std_Apr_s'
tand = 'pr_1x1_std_MJJASO_thailand'
predictors, predictand = load(tors, tand)
print(predictors.shape, predictand.shape)

import matplotlib.pyplot as plt
land = predictors[0, :, :, :, :]
plt.imshow(mask(land[0,0]))
plt.colorbar()
plt.show()

import numpy as np
land = mask(land)
std_map = np.empty((120, 360))
for i in range(120):
    for j in range(360):
        std = np.std(land[:, :, i, j].reshape(-1))
        std_map[i,j] = std
plt.imshow(std_map)
plt.colorbar()
plt.show()
# Out:
# (1, 42, 165, 120, 360) (42, 165, 20, 20)

# %%
tors = 'predictors_std_Apr_m'
tand = 'pr_1x1_std_MJJASO_thailand'
predictors, predictand = load(tors, tand)
print(predictors.shape, predictand.shape)

import matplotlib.pyplot as plt
land = predictors[0, :, :, :, :]
plt.imshow(mask(land[0,0]))
plt.colorbar()
plt.show()

import numpy as np
land = mask(land)
std_map = np.empty((120, 360))
for i in range(120):
    for j in range(360):
        std = np.std(land[:, :, i, j].reshape(-1))
        std_map[i,j] = std
plt.imshow(std_map)
plt.colorbar()
plt.show()
# Out:
# (1, 42, 165, 120, 360) (42, 165, 20, 20)

# %%
tors = 'predictors_std_Apr_t'
tand = 'pr_1x1_std_MJJASO_thailand'
predictors, predictand = load(tors, tand)
print(predictors.shape, predictand.shape)

import matplotlib.pyplot as plt
land = predictors[0, :, :, :, :]
plt.imshow(mask(land[0,0]))
plt.colorbar()
plt.show()

import numpy as np
land = mask(land)
std_map = np.empty((120, 360))
for i in range(120):
    for j in range(360):
        std = np.std(land[:, :, i, j].reshape(-1))
        std_map[i,j] = std
plt.imshow(std_map)
plt.colorbar()
plt.show()
# Out:
# (1, 42, 165, 120, 360) (42, 165, 20, 20)
# /tmp/ipykernel_693/3780164720.py:18: UserWarning: Warning: converting a masked element to nan.
#   std_map[i,j] = std

# %%
# lat = 60-y
x1, x2 = 65, 113
y1, y2 = 16, 28

land = predictors[0, :, :, y1:y2, x1:x2]
print(land.shape)
plt.imshow(mask(land[0,0]))
plt.show()

plt.imshow(std_map[y1:y2, x1:x2])
plt.show()
# Out:
# (42, 165, 12, 48)

# %% [markdown]
# # raw data のvariationを調べる

# %%
tors = 'predictors_raw_Apr_t'
tand = 'pr_1x1_std_MJJASO_thailand'
predictors, predictand = load(tors, tand)
print(predictors.shape, predictand.shape)

import matplotlib.pyplot as plt
land = predictors[0, :, :, :, :]
plt.imshow(mask(land[4,3]))
plt.colorbar()
plt.show()

import numpy as np
land = mask(land)
std_map = np.empty((120, 360))
for i in range(120):
    for j in range(360):
        std = np.std(land[:, :, i, j].reshape(-1))
        std_map[i,j] = std
plt.imshow(std_map)
plt.colorbar()
plt.show()
# Out:
# (1, 42, 165, 120, 360) (42, 165, 20, 20)
# /tmp/ipykernel_693/930824309.py:18: UserWarning: Warning: converting a masked element to nan.
#   std_map[i,j] = std
